# %%
# Om Shri Vighna Ganapathi Namo Namaha
# Om Shri Vighna Ganapathi Namo Namaha
# Om Shri Vighna Ganapathi Namo Namaha

# %%
import pandas as pd

# %% [markdown]
# ## Manually creating data and loading it to a DataFrame

# %%
data = {
    'Name' : ["SriRama","DivyaRama","SriKrishna"],
    'Age' : [35,33,2],
    'Place' : ["USA","New York","Washington DC"]
    
}

# %%
dataset = pd.DataFrame(data)

# %%
dataset
# Out:
#          Name  Age          Place
# 0     SriRama   35            USA
# 1   DivyaRama   33       New York
# 2  SriKrishna    2  Washington DC

# %% [markdown]
# ### Loading data from a CSV file to Dataframe

# %%
df = pd.read_csv(r"D:\SriKrishna\Sai - FSDS - Global AI Engineer\Sai - Programs\Data-Source\orders.csv")

# %%
df
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.info() # Print a concise summary of a DataFrame.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       40 non-null     int64
#  1   CustomerName  40 non-null     object
#  2   Product       40 non-null     object
#  3   Category      40 non-null     object
#  4   Quantity      40 non-null     int64
#  5   Price         40 non-null     float64
#  6   OrderDate     40 non-null     object
#  7   Shipped       40 non-null     object
#  8   Country       40 non-null     object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 2.9+ KB

# %%
df.head()
# Out:
#    OrderID   CustomerName       Product     Category  Quantity   Price  \
# 0     1001     John Smith        Laptop  Electronics         1  1200.0
# 1     1002      Sarah Lee    Headphones  Electronics         2   150.0
# 2     1003       Ali Khan  Office Chair    Furniture         1   300.0
# 3     1004     Alice Wong     Desk Lamp    Furniture         3    45.0
# 4     1005  Carlos Mendez      Keyboard  Electronics         2    80.0
#
#     OrderDate Shipped    Country
# 0  2024-06-01     Yes        USA
# 1  2024-06-03      No     Canada
# 2  2024-06-04     Yes        UAE
# 3  2024-06-05     Yes  Singapore
# 4  2024-06-06      No     Mexico

# %%
df.tail()
# Out:
#     OrderID    CustomerName             Product     Category  Quantity  Price  \
# 35     1036   Emma Thompson  Desk Lamp with USB    Furniture         1   68.0
# 36     1037   Carlos Santos    Wireless Earbuds  Electronics         1  125.0
# 37     1038  Leila Mansouri            Desk Pad    Furniture         1   28.0
# 38     1039      Daniel Kim         Power Strip  Electronics         2   18.0
# 39     1040    Anna Ivanova          Desk Clock    Furniture         1   35.0
#
#      OrderDate Shipped      Country
# 35  2024-07-07      No           UK
# 36  2024-07-08     Yes     Portugal
# 37  2024-07-09     Yes         Iran
# 38  2024-07-10      No  South Korea
# 39  2024-07-11     Yes      Ukraine

# %%
df.describe() # generates Descrptive Statistics
# Out:
#            OrderID    Quantity        Price
# count    40.000000   40.000000    40.000000
# mean   1020.500000    5.450000   106.457500
# std      11.690452   15.903475   201.091854
# min    1001.000000    1.000000     0.800000
# 25%    1010.750000    1.000000    18.000000
# 50%    1020.500000    1.000000    43.500000
# 75%    1030.250000    2.250000   112.500000
# max    1040.000000  100.000000  1200.000000

# %%
df.columns
# Out:
# Index(['OrderID', 'CustomerName', 'Product', 'Category', 'Quantity', 'Price',
#        'OrderDate', 'Shipped', 'Country'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %%
df.loc[1:5]
# Out:
#    OrderID   CustomerName       Product     Category  Quantity  Price  \
# 1     1002      Sarah Lee    Headphones  Electronics         2  150.0
# 2     1003       Ali Khan  Office Chair    Furniture         1  300.0
# 3     1004     Alice Wong     Desk Lamp    Furniture         3   45.0
# 4     1005  Carlos Mendez      Keyboard  Electronics         2   80.0
# 5     1006   Nora Ibrahim      Notebook   Stationery         5    5.0
#
#     OrderDate Shipped    Country
# 1  2024-06-03      No     Canada
# 2  2024-06-04     Yes        UAE
# 3  2024-06-05     Yes  Singapore
# 4  2024-06-06      No     Mexico
# 5  2024-06-07     Yes        UAE

# %%
df.loc[20:30]
# Out:
#     OrderID     CustomerName            Product     Category  Quantity  Price  \
# 20     1021   David Thompson       Highlighters   Stationery         8    3.5
# 21     1022   Isabella Silva  Bluetooth Speaker  Electronics         1   95.0
# 22     1023   Oliver Schmidt       Office Plant    Furniture         2   35.0
# 23     1024       Zara Ahmed       Sticky Notes   Stationery        15    4.0
# 24     1025   Lucas Anderson       Tablet Stand  Electronics         1   28.0
# 25     1026     Chloe Dubois     Paper Shredder  Electronics         1   75.0
# 26     1027    Miguel Torres     Desk Chair Mat    Furniture         1   22.0
# 27     1028      Nina Petrov       Binder Clips   Stationery        12    2.5
# 28     1029     Seo-yeon Kim  Wireless Keyboard  Electronics         1  110.0
# 29     1030  Giuseppe Romano      Desk Calendar    Furniture         1   18.0
# 30     1031     Amira Hassan            USB Hub  Electronics         1   32.0
#
# ...

# %%
df['OrderDate']
# Out:
# 0     2024-06-01
# 1     2024-06-03
# 2     2024-06-04
# 3     2024-06-05
# 4     2024-06-06
# 5     2024-06-07
# 6     2024-06-08
# 7     2024-06-09
# 8     2024-06-10
# 9     2024-06-11
# 10    2024-06-12
# 11    2024-06-13
# 12    2024-06-14
# 13    2024-06-15
# 14    2024-06-16
# 15    2024-06-17
# 16    2024-06-18
# 17    2024-06-19
# 18    2024-06-20
# 19    2024-06-21
# 20    2024-06-22
# 21    2024-06-23
# 22    2024-06-24
# 23    2024-06-25
# 24    2024-06-26
# 25    2024-06-27
# 26    2024-06-28
# 27    2024-06-29
# 28    2024-06-30
# 29    2024-07-01
# 30    2024-07-02
# 31    2024-07-03
# 32    2024-07-04
# 33    2024-07-05
# 34    2024-07-06
# 35    2024-07-07
# 36    2024-07-08
# 37    2024-07-09
# 38    2024-07-10
# 39    2024-07-11
# Name: OrderDate, dtype: object

# %%
df[['OrderID','OrderDate']]
# Out:
#     OrderID   OrderDate
# 0      1001  2024-06-01
# 1      1002  2024-06-03
# 2      1003  2024-06-04
# 3      1004  2024-06-05
# 4      1005  2024-06-06
# 5      1006  2024-06-07
# 6      1007  2024-06-08
# 7      1008  2024-06-09
# 8      1009  2024-06-10
# 9      1010  2024-06-11
# 10     1011  2024-06-12
# 11     1012  2024-06-13
# 12     1013  2024-06-14
# 13     1014  2024-06-15
# 14     1015  2024-06-16
# 15     1016  2024-06-17
# 16     1017  2024-06-18
# 17     1018  2024-06-19
# 18     1019  2024-06-20
# 19     1020  2024-06-21
# 20     1021  2024-06-22
# 21     1022  2024-06-23
# 22     1023  2024-06-24
# 23     1024  2024-06-25
# 24     1025  2024-06-26
# 25     1026  2024-06-27
# 26     1027  2024-06-28
# 27     1028  2024-06-29
# 28     1029  2024-06-30
# 29     1030  2024-07-01
# 30     1031  2024-07-02
# 31     1032  2024-07-03
# 32     1033  2024-07-04
# 33     1034  2024-07-05
# 34     1035  2024-07-06
# 35     1036  2024-07-07
# 36     1037  2024-07-08
# ...

# %%
df.loc[:,'OrderDate']
# Out:
# 0     2024-06-01
# 1     2024-06-03
# 2     2024-06-04
# 3     2024-06-05
# 4     2024-06-06
# 5     2024-06-07
# 6     2024-06-08
# 7     2024-06-09
# 8     2024-06-10
# 9     2024-06-11
# 10    2024-06-12
# 11    2024-06-13
# 12    2024-06-14
# 13    2024-06-15
# 14    2024-06-16
# 15    2024-06-17
# 16    2024-06-18
# 17    2024-06-19
# 18    2024-06-20
# 19    2024-06-21
# 20    2024-06-22
# 21    2024-06-23
# 22    2024-06-24
# 23    2024-06-25
# 24    2024-06-26
# 25    2024-06-27
# 26    2024-06-28
# 27    2024-06-29
# 28    2024-06-30
# 29    2024-07-01
# 30    2024-07-02
# 31    2024-07-03
# 32    2024-07-04
# 33    2024-07-05
# 34    2024-07-06
# 35    2024-07-07
# 36    2024-07-08
# 37    2024-07-09
# 38    2024-07-10
# 39    2024-07-11
# Name: OrderDate, dtype: object

# %%
df.columns
# Out:
# Index(['OrderID', 'CustomerName', 'Product', 'Category', 'Quantity', 'Price',
#        'OrderDate', 'Shipped', 'Country'],
#       dtype='object')

# %%
df.iloc[1]
# Out:
# OrderID                1002
# CustomerName      Sarah Lee
# Product          Headphones
# Category        Electronics
# Quantity                  2
# Price                 150.0
# OrderDate        2024-06-03
# Shipped                  No
# Country              Canada
# Name: 1, dtype: object

# %%
list(df.iloc[10])
# Out:
# [1011,
#  'Sophie Martin',
#  'Webcam',
#  'Electronics',
#  1,
#  85.0,
#  '2024-06-12',
#  'Yes',
#  'France']

# %%
df.iat[10,1]
# Out:
# 'Sophie Martin'

# %%
df.iat[5,6]
# Out:
# '2024-06-07'

# %%
df.at[5,'OrderDate']
# Out:
# '2024-06-07'

# %%
df.at[10,'CustomerName']
# Out:
# 'Sophie Martin'

# %%
df.loc[:,['CustomerName']]
# Out:
#         CustomerName
# 0         John Smith
# 1          Sarah Lee
# 2           Ali Khan
# 3         Alice Wong
# 4      Carlos Mendez
# 5       Nora Ibrahim
# 6        Emily Davis
# 7         James Park
# 8        Maria Rossi
# 9   Takeshi Nakamura
# 10     Sophie Martin
# 11         Raj Patel
# 12       Emma Wilson
# 13   Diego Rodriguez
# 14         Lisa Chen
# 15      Ahmed Hassan
# 16     Anna Kowalski
# 17     Michael Brown
# 18       Yuki Tanaka
# 19   Fatima Al-Zahra
# 20    David Thompson
# 21    Isabella Silva
# 22    Oliver Schmidt
# 23        Zara Ahmed
# 24    Lucas Anderson
# 25      Chloe Dubois
# 26     Miguel Torres
# 27       Nina Petrov
# 28      Seo-yeon Kim
# 29   Giuseppe Romano
# 30      Amira Hassan
# 31     Thomas Müller
# 32   Sofia Rodriguez
# 33      Alex Johnson
# 34     Yuki Yamamoto
# 35     Emma Thompson
# 36     Carlos Santos
# 37    Leila Mansouri
# 38        Daniel Kim
# 39      Anna Ivanova

# %% [markdown]
# ### Filtering

# %%
df[df["Category"] == "Electronics"]
# Out:
#     OrderID      CustomerName            Product     Category  Quantity  \
# 0      1001        John Smith             Laptop  Electronics         1
# 1      1002         Sarah Lee         Headphones  Electronics         2
# 4      1005     Carlos Mendez           Keyboard  Electronics         2
# 7      1008        James Park            Monitor  Electronics         2
# 9      1010  Takeshi Nakamura              Mouse  Electronics         1
# 10     1011     Sophie Martin             Webcam  Electronics         1
# 13     1014   Diego Rodriguez          USB Drive  Electronics         5
# 16     1017     Anna Kowalski     Wireless Mouse  Electronics         2
# 18     1019       Yuki Tanaka         Calculator  Electronics         1
# 21     1022    Isabella Silva  Bluetooth Speaker  Electronics         1
# 24     1025    Lucas Anderson       Tablet Stand  Electronics         1
# 25     1026      Chloe Dubois     Paper Shredder  Electronics         1
# ...

# %%
df[(df["Category"]=="Electronics") & (df["Country"]=="USA")]
# Out:
#    OrderID CustomerName Product     Category  Quantity   Price   OrderDate  \
# 0     1001   John Smith  Laptop  Electronics         1  1200.0  2024-06-01
#
#   Shipped Country
# 0     Yes     USA

# %%
df[(df["Category"]=="Electronics")|(df["Country"]=="USA")]
# Out:
#     OrderID      CustomerName            Product     Category  Quantity  \
# 0      1001        John Smith             Laptop  Electronics         1
# 1      1002         Sarah Lee         Headphones  Electronics         2
# 4      1005     Carlos Mendez           Keyboard  Electronics         2
# 7      1008        James Park            Monitor  Electronics         2
# 9      1010  Takeshi Nakamura              Mouse  Electronics         1
# 10     1011     Sophie Martin             Webcam  Electronics         1
# 13     1014   Diego Rodriguez          USB Drive  Electronics         5
# 16     1017     Anna Kowalski     Wireless Mouse  Electronics         2
# 17     1018     Michael Brown     Desk Organizer    Furniture         1
# 18     1019       Yuki Tanaka         Calculator  Electronics         1
# 21     1022    Isabella Silva  Bluetooth Speaker  Electronics         1
# 24     1025    Lucas Anderson       Tablet Stand  Electronics         1
# ...

# %%
df[df["Quantity"]>20]
# Out:
#     OrderID  CustomerName      Product    Category  Quantity  Price  \
# 33     1034  Alex Johnson  Index Cards  Stationery       100    0.8
#
#      OrderDate Shipped Country
# 33  2024-07-05     Yes     USA

# %%
df[df["Quantity"] > 2]
# Out:
#     OrderID     CustomerName        Product     Category  Quantity  Price  \
# 3      1004       Alice Wong      Desk Lamp    Furniture         3   45.0
# 5      1006     Nora Ibrahim       Notebook   Stationery         5    5.0
# 8      1009      Maria Rossi            Pen   Stationery        10    1.5
# 12     1013      Emma Wilson        Stapler   Stationery         3   12.0
# 13     1014  Diego Rodriguez      USB Drive  Electronics         5   25.0
# 15     1016     Ahmed Hassan  Printer Paper   Stationery        20    8.0
# 20     1021   David Thompson   Highlighters   Stationery         8    3.5
# 23     1024       Zara Ahmed   Sticky Notes   Stationery        15    4.0
# 27     1028      Nina Petrov   Binder Clips   Stationery        12    2.5
# 33     1034     Alex Johnson    Index Cards   Stationery       100    0.8
#
#      OrderDate Shipped    Country
# 3   2024-06-05     Yes  Singapore
# 5   2024-06-07     Yes        UAE
# 8   2024-06-10     Yes      Italy
# ...

# %%
df[df["CustomerName"].str.endswith("a")]
# Out:
#     OrderID      CustomerName            Product     Category  Quantity  \
# 9      1010  Takeshi Nakamura              Mouse  Electronics         1
# 18     1019       Yuki Tanaka         Calculator  Electronics         1
# 19     1020   Fatima Al-Zahra         Whiteboard    Furniture         1
# 21     1022    Isabella Silva  Bluetooth Speaker  Electronics         1
# 39     1040      Anna Ivanova         Desk Clock    Furniture         1
#
#     Price   OrderDate Shipped       Country
# 9    35.0  2024-06-11     Yes         Japan
# 18   15.0  2024-06-20     Yes         Japan
# 19  120.0  2024-06-21     Yes  Saudi Arabia
# 21   95.0  2024-06-23     Yes        Brazil
# 39   35.0  2024-07-11     Yes       Ukraine

# %%
df[df["CustomerName"].str.startswith("A")]
# Out:
#     OrderID   CustomerName         Product     Category  Quantity  Price  \
# 2      1003       Ali Khan    Office Chair    Furniture         1  300.0
# 3      1004     Alice Wong       Desk Lamp    Furniture         3   45.0
# 15     1016   Ahmed Hassan   Printer Paper   Stationery        20    8.0
# 16     1017  Anna Kowalski  Wireless Mouse  Electronics         2   45.0
# 30     1031   Amira Hassan         USB Hub  Electronics         1   32.0
# 33     1034   Alex Johnson     Index Cards   Stationery       100    0.8
# 39     1040   Anna Ivanova      Desk Clock    Furniture         1   35.0
#
#      OrderDate Shipped    Country
# 2   2024-06-04     Yes        UAE
# 3   2024-06-05     Yes  Singapore
# 15  2024-06-17     Yes      Egypt
# 16  2024-06-18     Yes     Poland
# 30  2024-07-02     Yes    Morocco
# 33  2024-07-05     Yes        USA
# 39  2024-07-11     Yes    Ukraine

# %%
df[df["Country"].isin(["USA", "India", "Sweden"])]
# Out:
#     OrderID    CustomerName         Product     Category  Quantity   Price  \
# 0      1001      John Smith          Laptop  Electronics         1  1200.0
# 11     1012       Raj Patel    File Cabinet    Furniture         2   180.0
# 17     1018   Michael Brown  Desk Organizer    Furniture         1    65.0
# 24     1025  Lucas Anderson    Tablet Stand  Electronics         1    28.0
# 33     1034    Alex Johnson     Index Cards   Stationery       100     0.8
#
#      OrderDate Shipped Country
# 0   2024-06-01     Yes     USA
# 11  2024-06-13      No   India
# 17  2024-06-19      No     USA
# 24  2024-06-26     Yes  Sweden
# 33  2024-07-05     Yes     USA

# %%
df[~df["Country"].isin(["USA","India","Sweden"])]
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# 12     1013       Emma Wilson                Stapler   Stationery         3
# ...

# %%
len(df[~df["Country"].isin(["USA","India","Sweden"])])
# Out:
# 35

# %%
df.loc[df["CustomerName"] == "Daniel Kim", "Product"] = "Table"

# %%
df.loc[df["CustomerName"]== "Daniel Kim"]
# Out:
#     OrderID CustomerName Product     Category  Quantity  Price   OrderDate  \
# 38     1039   Daniel Kim   Table  Electronics         2   18.0  2024-07-10
#
#    Shipped      Country
# 38      No  South Korea

# %%
df.loc[df["Country"]=="Pakistan", "Country"] = "India"

# %%
df.loc[df["Country"]=="India"]
# Out:
#     OrderID CustomerName       Product    Category  Quantity  Price  \
# 11     1012    Raj Patel  File Cabinet   Furniture         2  180.0
# 23     1024   Zara Ahmed  Sticky Notes  Stationery        15    4.0
#
#      OrderDate Shipped Country
# 11  2024-06-13      No   India
# 23  2024-06-25      No   India

# %%
df.loc[df["Country"]=="Pakistan"] #returns None as we've changed Pakistan to India
# Out:
# Empty DataFrame
# Columns: [OrderID, CustomerName, Product, Category, Quantity, Price, OrderDate, Shipped, Country]
# Index: []

# %%
df["Country"] = df["Country"].str.upper()

# %%
df["Country"]
# Out:
# 0              USA
# 1           CANADA
# 2              UAE
# 3        SINGAPORE
# 4           MEXICO
# 5              UAE
# 6               UK
# 7      SOUTH KOREA
# 8            ITALY
# 9            JAPAN
# 10          FRANCE
# 11           INDIA
# 12       AUSTRALIA
# 13           SPAIN
# 14           CHINA
# 15           EGYPT
# 16          POLAND
# 17             USA
# 18           JAPAN
# 19    SAUDI ARABIA
# 20          CANADA
# 21          BRAZIL
# 22         GERMANY
# 23           INDIA
# 24          SWEDEN
# 25          FRANCE
# 26       ARGENTINA
# 27          RUSSIA
# 28     SOUTH KOREA
# 29           ITALY
# 30         MOROCCO
# 31         GERMANY
# 32        COLOMBIA
# 33             USA
# 34           JAPAN
# 35              UK
# 36        PORTUGAL
# 37            IRAN
# 38     SOUTH KOREA
# 39         UKRAINE
# Name: Country, dtype: object

# %%
df.drop(39, inplace=True)

# %%
df.tail()
# Out:
#     OrderID    CustomerName             Product     Category  Quantity  Price  \
# 34     1035   Yuki Yamamoto       Monitor Stand  Electronics         1   55.0
# 35     1036   Emma Thompson  Desk Lamp with USB    Furniture         1   68.0
# 36     1037   Carlos Santos    Wireless Earbuds  Electronics         1  125.0
# 37     1038  Leila Mansouri            Desk Pad    Furniture         1   28.0
# 38     1039      Daniel Kim               Table  Electronics         2   18.0
#
#      OrderDate Shipped      Country       Contry
# 34  2024-07-06     Yes        JAPAN        JAPAN
# 35  2024-07-07      No           UK           UK
# 36  2024-07-08     Yes     PORTUGAL     PORTUGAL
# 37  2024-07-09     Yes         IRAN         IRAN
# 38  2024-07-10      No  SOUTH KOREA  SOUTH KOREA

# %%
df.dropna()
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.fillna("OrderID" == 1039)
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df["Country"].value_counts()
# Out:
# Country
# USA             3
# SOUTH KOREA     3
# JAPAN           3
# UK              2
# UAE             2
# ITALY           2
# FRANCE          2
# INDIA           2
# CANADA          2
# GERMANY         2
# PORTUGAL        1
# COLOMBIA        1
# BRAZIL          1
# MOROCCO         1
# RUSSIA          1
# ARGENTINA       1
# SWEDEN          1
# CHINA           1
# SAUDI ARABIA    1
# POLAND          1
# EGYPT           1
# SPAIN           1
# AUSTRALIA       1
# MEXICO          1
# SINGAPORE       1
# IRAN            1
# Name: count, dtype: int64

# %%
df["Country"] = df["Country"].str.lower()

# %%
df["Country"]
# Out:
# 0              usa
# 1           canada
# 2              uae
# 3        singapore
# 4           mexico
# 5              uae
# 6               uk
# 7      south korea
# 8            italy
# 9            japan
# 10          france
# 11           india
# 12       australia
# 13           spain
# 14           china
# 15           egypt
# 16          poland
# 17             usa
# 18           japan
# 19    saudi arabia
# 20          canada
# 21          brazil
# 22         germany
# 23        pakistan
# 24          sweden
# 25          france
# 26       argentina
# 27          russia
# 28     south korea
# 29           italy
# 30         morocco
# 31         germany
# 32        colombia
# 33             usa
# 34           japan
# 35              uk
# 36        portugal
# 37            iran
# 38     south korea
# 39         ukraine
# Name: Country, dtype: object

# %%
df["Country"].value_counts()
# Out:
# Country
# usa             3
# south korea     3
# japan           3
# uk              2
# uae             2
# italy           2
# germany         2
# france          2
# canada          2
# iran            1
# portugal        1
# colombia        1
# morocco         1
# russia          1
# argentina       1
# sweden          1
# pakistan        1
# egypt           1
# brazil          1
# saudi arabia    1
# poland          1
# china           1
# spain           1
# australia       1
# india           1
# mexico          1
# singapore       1
# ukraine         1
# Name: count, dtype: int64

# %%
df["Country"] = df["Country"].str.capitalize()

# %%
df["Country"]
# Out:
# 0              Usa
# 1           Canada
# 2              Uae
# 3        Singapore
# 4           Mexico
# 5              Uae
# 6               Uk
# 7      South korea
# 8            Italy
# 9            Japan
# 10          France
# 11           India
# 12       Australia
# 13           Spain
# 14           China
# 15           Egypt
# 16          Poland
# 17             Usa
# 18           Japan
# 19    Saudi arabia
# 20          Canada
# 21          Brazil
# 22         Germany
# 23        Pakistan
# 24          Sweden
# 25          France
# 26       Argentina
# 27          Russia
# 28     South korea
# 29           Italy
# 30         Morocco
# 31         Germany
# 32        Colombia
# 33             Usa
# 34           Japan
# 35              Uk
# 36        Portugal
# 37            Iran
# 38     South korea
# 39         Ukraine
# Name: Country, dtype: object

# %%
df["Country"].value_counts()
# Out:
# Country
# Usa             3
# South korea     3
# Japan           3
# Uk              2
# Uae             2
# Italy           2
# Germany         2
# France          2
# Canada          2
# Iran            1
# Portugal        1
# Colombia        1
# Morocco         1
# Russia          1
# Argentina       1
# Sweden          1
# Pakistan        1
# Egypt           1
# Brazil          1
# Saudi arabia    1
# Poland          1
# China           1
# Spain           1
# Australia       1
# India           1
# Mexico          1
# Singapore       1
# Ukraine         1
# Name: count, dtype: int64

# %%
df.loc[df["Country"]=="Pakistan", "Country"] = "India"

# %%
df["Country"].value_counts()
# Out:
# Country
# Usa             3
# South korea     3
# Japan           3
# Uk              2
# Uae             2
# Italy           2
# Germany         2
# France          2
# India           2
# Canada          2
# Iran            1
# Portugal        1
# Colombia        1
# Morocco         1
# Russia          1
# Argentina       1
# Sweden          1
# China           1
# Brazil          1
# Saudi arabia    1
# Poland          1
# Egypt           1
# Spain           1
# Australia       1
# Mexico          1
# Singapore       1
# Ukraine         1
# Name: count, dtype: int64

# %%
df.groupby("Country")["Price"].sum()
# Out:
# Country
# Argentina         22.0
# Australia         12.0
# Brazil            95.0
# Canada           153.5
# China            280.0
# Colombia          42.0
# Egypt              8.0
# France           160.0
# Germany          175.0
# India            184.0
# Iran              28.0
# Italy             19.5
# Japan            105.0
# Mexico            80.0
# Morocco           32.0
# Poland            45.0
# Portugal         125.0
# Russia             2.5
# Saudi arabia     120.0
# Singapore         45.0
# South korea      348.0
# Spain             25.0
# Sweden            28.0
# Uae              305.0
# Uk               518.0
# Ukraine           35.0
# Usa             1265.8
# Name: Price, dtype: float64

# %%
df.sort_values("Price")
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 33     1034      Alex Johnson            Index Cards   Stationery       100
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 27     1028       Nina Petrov           Binder Clips   Stationery        12
# 20     1021    David Thompson           Highlighters   Stationery         8
# 23     1024        Zara Ahmed           Sticky Notes   Stationery        15
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 15     1016      Ahmed Hassan          Printer Paper   Stationery        20
# 12     1013       Emma Wilson                Stapler   Stationery         3
# 18     1019       Yuki Tanaka             Calculator  Electronics         1
# 29     1030   Giuseppe Romano          Desk Calendar    Furniture         1
# 38     1039        Daniel Kim            Power Strip  Electronics         2
# ...

# %%
df.sort_values("Price", ascending=False)
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 14     1015         Lisa Chen              Bookshelf    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 11     1012         Raj Patel           File Cabinet    Furniture         2
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 31     1032     Thomas Müller       Document Scanner  Electronics         1
# 36     1037     Carlos Santos       Wireless Earbuds  Electronics         1
# 19     1020   Fatima Al-Zahra             Whiteboard    Furniture         1
# 28     1029      Seo-yeon Kim      Wireless Keyboard  Electronics         1
# ...

# %%
df.to_csv("updated.csv", index=True)
